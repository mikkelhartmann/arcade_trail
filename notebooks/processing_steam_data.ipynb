# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import csv
import re
import gensim
import h5py
import time
from collections import Counter

from nltk.stem.wordnet import WordNetLemmatizer
from nltk.corpus import stopwords

from sklearn.linear_model import LogisticRegression
from sklearn.base import clone
from sklearn.pipeline import Pipeline
from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.externals import joblib

from keras.preprocessing import sequence
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation
from keras.layers import Embedding
from keras.layers import LSTM
from keras.layers import Conv1D, MaxPooling1D
from keras.models import load_model

# %matplotlib inline
import helper_function as hf
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Loading descriptions

# %%
with open('data/steam_game_descriptions_2.txt', 'r') as f:
  reader = csv.reader(f)
  descriptions = list(reader)

# %%
descriptions = descriptions[0]

# %%
len(descriptions)
# Out:
# 49556

# %% [markdown]
# # Loading tag names

# %% [markdown]
# The tags names appear in the same order as the columns of the target matrix.

# %%
with open('data/steam_complete_tag_list_2.txt', 'r') as f:
  reader = csv.reader(f)
  tag_names = list(reader)

# %%
tag_names = tag_names[0]

# %%
len(tag_names)
# Out:
# 337

# %% [markdown]
# # Loading target matrix

# %% [markdown]
# A matrix with a row for each game and a column for each tag. Each element in the matrix in a binary indicator that is 1 in the columns if the game has the tag.

# %%
y_mat = np.load('data/steam_tag_metrix_3.npy')

# %%
len(y_mat)
# Out:
# 49556

# %% [markdown]
# # Looking at the distribution across genres

# %%
aggregate = sum(y_mat)
sort_idx = sorted(range(len(aggregate)), key=lambda k: aggregate[k], reverse=True)
y_label_names = [tag_names[idx] for idx in sort_idx]

# %%
for idx, sorted_idx in enumerate(sort_idx):
    print(idx, tag_names[idx], aggregate[idx])
# Out:
# 0 Animation & Modeling 433.0
# 1 Video Production 219.0
# 2 Free to Play 3662.0
# 3 Software 412.0
# 4 Movie 353.0
# 5 Sandbox 1858.0
# 6 Difficult 2158.0
# 7 Action 19256.0
# 8 Funny 1851.0
# 9 Comedy 1540.0
# 10 Singleplayer 8076.0
# 11 Moddable 557.0
# 12 Multiplayer 4637.0
# 13 Horror 2068.0
# 14 Anime 1929.0
# 15 First-Person 2047.0
# 16 Character Customization 332.0
# 17 Crafting 557.0
# 18 Great Soundtrack 3764.0
# 19 Strategy 12328.0
# 20 RTS 1009.0
# 21 Sci-fi 2623.0
# 22 Futuristic 315.0
# 23 RPG 9228.0
# 24 Open World 2587.0
# 25 Fantasy 2390.0
# 26 Third Person 1276.0
# 27 Adventure 15045.0
# 28 Medieval 409.0
# 29 Action RPG 641.0
# 30 Story Rich 2198.0
# 31 Dark Fantasy 318.0
# 32 Swordplay 91.0
# 33 Magic 276.0
# 34 Classic 1739.0
# 35 Multiple Endings 205.0
# 36 Stealth 541.0
# 37 Atmospheric 3212.0
# 38 Hack and Slash 559.0
# 39 Gore 739.0
# 40 FPS 1738.0
# 41 Arena Shooter 206.0
# 42 Competitive 449.0
# 43 Shooter 2282.0
# 44 1990's 285.0
# 45 Fast-Paced 567.0
# 46 e-sports 104.0
# 47 World War II 514.0
# 48 Retro 1685.0
# 49 Pixel Graphics 2215.0
# 50 Demons 127.0
# 51 Violent 205.0
# 52 2.5D 167.0
# 53 Zombies 898.0
# 54 Online Co-Op 918.0
# 55 Lovecraftian 182.0
# 56 Co-op 2345.0
# 57 Class-Based 53.0
# 58 Indie 26171.0
# 59 Mystery 707.0
# 60 Assassin 67.0
# 61 Survival 1443.0
# 62 Simulation 12940.0
# 63 Replay Value 656.0
# 64 Stylized 206.0
# 65 Top-Down Shooter 313.0
# 66 Local Co-Op 996.0
# 67 Aliens 304.0
# 68 Top-Down 501.0
# 69 Isometric 477.0
# 70 Casual 13989.0
# 71 Arcade 1652.0
# 72 2D 3207.0
# 73 Puzzle 3660.0
# 74 Space 1432.0
# 75 Vampire 92.0
# 76 Cult Classic 205.0
# 77 Supernatural 75.0
# 78 Dark 531.0
# 79 Female Protagonist 2031.0
# 80 Gothic 100.0
# 81 Western 112.0
# 82 Third-Person Shooter 478.0
# 83 War 535.0
# 84 Historical 705.0
# 85 Military 380.0
# 86 Linear 82.0
# 87 America 88.0
# 88 Management 643.0
# 89 Building 680.0
# 90 Economy 313.0
# 91 Real-Time with Pause 237.0
# 92 Family Friendly 1306.0
# 93 Tactical 952.0
# 94 Space Sim 216.0
# 95 Trading 115.0
# 96 Flight 340.0
# 97 Capitalism 49.0
# 98 4X 256.0
# 99 Exploration 1069.0
# 100 Naval 187.0
# 101 Racing 2023.0
# 102 Destruction 225.0
# 103 Music 513.0
# 104 Driving 374.0
# 105 Physics 866.0
# 106 Offroad 55.0
# 107 Turn-Based Strategy 905.0
# 108 Hex Grid 156.0
# 109 Turn-Based 1707.0
# 110 Point & Click 1856.0
# 111 Match 3 266.0
# 112 Underwater 104.0
# 113 Colorful 434.0
# 114 Typing 53.0
# 115 Education 598.0
# 116 Hidden Object 804.0
# 117 Tower Defense 569.0
# 118 Cute 915.0
# 119 Touch-Friendly 214.0
# 120 Post-apocalyptic 384.0
# 121 Sniper 28.0
# 122 Cyberpunk 397.0
# 123 Comic Book 102.0
# 124 Base Building 289.0
# 125 Villain Protagonist 105.0
# 126 Parody 104.0
# 127 Platformer 2676.0
# 128 3D Platformer 275.0
# 129 Psychological 91.0
# 130 Cartoony 213.0
# 131 Surreal 308.0
# 132 Action-Adventure 451.0
# 133 3D Vision 154.0
# 134 Soundtrack 215.0
# 135 Grand Strategy 361.0
# 136 Resource Management 190.0
# 137 Pirates 181.0
# 138 Sailing 47.0
# 139 Remake 195.0
# 140 Fighting 409.0
# 141 Choose Your Own Adventure 289.0
# 142 City Builder 340.0
# 143 Rome 69.0
# 144 Mod 151.0
# 145 Massively Multiplayer 2027.0
# 146 Card Game 379.0
# 147 Sports 2359.0
# 148 Robots 370.0
# 149 Loot 171.0
# 150 Survival Horror 480.0
# 151 Based On A Novel 37.0
# 152 Inventory Management 33.0
# 153 Real Time Tactics 153.0
# 154 Team-Based 188.0
# 155 Star Wars 95.0
# 156 Beat 'em up 348.0
# 157 Side Scroller 608.0
# 158 Short 629.0
# 159 Controller 838.0
# 160 MOBA 171.0
# 161 PvP 445.0
# 162 Mechs 196.0
# 163 Spectacle fighter 35.0
# 164 Character Action Game 69.0
# 165 Twin Stick Shooter 345.0
# 166 Shoot 'Em Up 997.0
# 167 Bullet Hell 544.0
# 168 Crime 165.0
# 169 Steampunk 303.0
# 170 Lara Croft 47.0
# 171 Martial Arts 53.0
# 172 Party-Based RPG 439.0
# 173 Romance 212.0
# 174 Choices Matter 276.0
# 175 Mythology 80.0
# 176 Level Editor 329.0
# 177 Time Attack 68.0
# 178 Detective 284.0
# 179 Nudity 427.0
# 180 Trains 353.0
# 181 Turn-Based Tactics 346.0
# 182 Dystopian 142.0
# 183 Political 76.0
# 184 Alternate History 104.0
# 185 Realistic 682.0
# 186 World War I 91.0
# 187 Modern 46.0
# 188 Hunting 130.0
# 189 Dinosaurs 144.0
# 190 Parkour 253.0
# 191 Heist 39.0
# 192 Split Screen 156.0
# 193 Episodic 242.0
# 194 Psychedelic 121.0
# 195 Score Attack 114.0
# 196 MMORPG 362.0
# 197 PvE 93.0
# 198 Superhero 145.0
# 199 Diplomacy 44.0
# 200 Mars 49.0
# 201 Tanks 137.0
# 202 Real-Time 143.0
# 203 Co-op Campaign 48.0
# 204 Local Multiplayer 918.0
# 205 Puzzle-Platformer 695.0
# 206 Cold War 103.0
# 207 Relaxing 437.0
# 208 1980s 131.0
# 209 On-Rails Shooter 54.0
# 210 Time Manipulation 56.0
# 211 Bullet Time 63.0
# 212 Time Travel 101.0
# 213 Mini Golf 26.0
# 214 Golf 42.0
# 215 Blood 98.0
# 216 Dark Humor 215.0
# 217 Satire 82.0
# 218 Mature 198.0
# 219 Bowling 22.0
# 220 Turn-Based Combat 309.0
# 221 Pinball 132.0
# 222 CRPG 128.0
# 223 Walking Simulator 496.0
# 224 Rhythm 198.0
# 225 Music-Based Procedural Generation 41.0
# 226 Procedural Generation 427.0
# 227 Ninja 113.0
# 228 Conspiracy 40.0
# 229 Horses 42.0
# 230 TrackIR 276.0
# 231 VR 1902.0
# 232 Early Access 2791.0
# 233 Warhammer 40K 72.0
# 234 Games Workshop 81.0
# 235 Cinematic 55.0
# 236 Agriculture 69.0
# 237 Psychological Horror 610.0
# 238 Benchmark 32.0
# 239 God Game 98.0
# 240 Science 99.0
# 241 Dragons 141.0
# 242 Silent Protagonist 38.0
# 243 FMV 113.0
# 244 Memes 517.0
# 245 Hacking 112.0
# 246 Experimental 169.0
# 247 Nonlinear 19.0
# 248 LEGO 66.0
# 249 Batman 29.0
# 250 2D Fighter 170.0
# 251 Voice Control 11.0
# 252 Gun Customization 25.0
# 253 4 Player Local 471.0
# 254 JRPG 453.0
# 255 Politics 86.0
# 256 Fishing 50.0
# 257 Metroidvania 344.0
# 258 Philisophical 16.0
# 259 6DOF 60.0
# 260 Wargame 162.0
# 261 Tactical RPG 108.0
# 262 Experience 14.0
# 263 Board Game 352.0
# 264 Abstract 158.0
# 265 Gambling 23.0
# 266 Conversation 7.0
# 267 Dating Sim 197.0
# 268 Quick-Time Events 47.0
# 269 Rogue-like 944.0
# 270 Perma Death 269.0
# 271 Noir 149.0
# 272 Hand-drawn 177.0
# 273 Mouse only 81.0
# 274 Dungeon Crawler 409.0
# 275 Cartoon 141.0
# 276 Lore-Rich 53.0
# 277 Strategy RPG 120.0
# 278 Basketball 30.0
# 279 Minimalist 289.0
# 280 Trading Card Game 118.0
# 281 Werewolves 31.0
# 282 Runner 87.0
# 283 Mining 26.0
# 284 Illuminati 242.0
# 285 Visual Novel 853.0
# 286 Lemmings 25.0
# 287 Programming 71.0
# 288 Narration 74.0
# 289 Drama 151.0
# 290 Interactive Fiction 182.0
# 291 GameMaker 150.0
# 292 Asynchronous Multiplayer 67.0
# 293 Chess 51.0
# 294 Rogue-lite 475.0
# 295 Documentary 140.0
# 296 Dynamic Narration 38.0
# 297 RPGMaker 757.0
# 298 Thriller 71.0
# 299 Grid-Based Movement 75.0
# 300 Kickstarter 259.0
# 301 Sexual Content 95.0
# 302 Transhumanism 4.0
# 303 Utilities 847.0
# 304 Otome 124.0
# 305 Football 104.0
# 306 Soccer 84.0
# 307 Voxel 154.0
# 308 Audio Production 323.0
# 309 Crowdfunded 87.0
# 310 NSFW 5.0
# 311 Game Development 301.0
# 312 Design & Illustration 907.0
# 313 Web Publishing 458.0
# 314 Photo Editing 103.0
# 315 Software Training 225.0
# 316 Intentionally Awkward Controls 11.0
# 317 Text-Based 128.0
# 318 Dark Comedy 37.0
# 319 Investigation 10.0
# 320 Sokoban 30.0
# 321 Artificial Intelligence 10.0
# 322 Gaming 90.0
# 323 Clicker 91.0
# 324 Pool 17.0
# 325 Underground 7.0
# 326 Wrestling 11.0
# 327 Steam Machine 41.0
# 328 Word Game 29.0
# 329 Tutorial 117.0
# 330 Spelling 13.0
# 331 Hardware 37.0
# 332 Feature Film 3.0
# 333 Mystery Dungeon 16.0
# 334 360 Video 11.0
# 335 Foreign 2.0
# 336 Faith 1.0

# %%
hf.plot_top_tags_barplot(y_label_names, aggregate, sort_idx, 20)

# %% [markdown]
# # Looking at a subset of the genres

# %% [markdown]
# Since many of the the tags, such as multiplayer, singleplayer, and free to play could belong to any genre, I have selected a subset of that tags that I bilieve will be easier and more interesting to predict.

# %%
idx_of_selected_tags = [
    13, 21, 22, 25, 28, 31, 33, 
    39, 47, 53, 59, 61, 67, 74, 77,
    78, 80, 81, 83, 84, 85, 100, 101,
    120, 122, 131, 137, 147, 148, 150,
    168, 169, 175, 182, 186, 194, 206,
    237, 241
    ]

# %% [markdown]
# Some of the items on steam are utility apps, such as game development or software training. The items may also be tagged with some of the tags we are interested in. We want to remove these utility apps from the dataset, since they are likely to have a different kind og description.

# %%
selected_tag_names = [tag_names[idx] for idx in idx_of_selected_tags]

# %%
np.save('data/selected_tag_names.npy', selected_tag_names)

# %%
for tag_idx in idx_of_selected_tags:
    print(tag_names[tag_idx], aggregate[tag_idx])
# Out:
# Horror 2068.0
# Sci-fi 2623.0
# Futuristic 315.0
# Fantasy 2390.0
# Medieval 409.0
# Dark Fantasy 318.0
# Magic 276.0
# Gore 739.0
# World War II 514.0
# Zombies 898.0
# Mystery 707.0
# Survival 1443.0
# Aliens 304.0
# Space 1432.0
# Supernatural 75.0
# Dark 531.0
# Gothic 100.0
# Western 112.0
# War 535.0
# Historical 705.0
# Military 380.0
# Naval 187.0
# Racing 2023.0
# Post-apocalyptic 384.0
# Cyberpunk 397.0
# Surreal 308.0
# Pirates 181.0
# Sports 2359.0
# Robots 370.0
# Survival Horror 480.0
# Crime 165.0
# Steampunk 303.0
# Mythology 80.0
# Dystopian 142.0
# World War I 91.0
# Psychedelic 121.0
# Cold War 103.0
# Psychological Horror 610.0
# Dragons 141.0

# %%
len(idx_of_selected_tags)
# Out:
# 39

# %%
idx_of_utility_tags = [
    1, 3, 303, 308, 312, 313, 314, 315
]

# %%
for tag_idx in idx_of_utility_tags:
    print(tag_names[tag_idx], aggregate[tag_idx])
# Out:
# Video Production 219.0
# Software 412.0
# Utilities 847.0
# Audio Production 323.0
# Design & Illustration 907.0
# Web Publishing 458.0
# Photo Editing 103.0
# Software Training 225.0

# %% [markdown]
# # Subsetting the data

# %% [markdown]
# ## Getting the descriptions with one or more of the subtags

# %% [markdown]
# Below i create two lists. One list contains the game description that meet two criteria: 1) It must contain at least one of the tags that we are interested in training our model on and 2) it must not contain any of the utility tags, since we do not want any descriptions of game development software in our dataset.
#
# The second list is a list of the indices for the relevant description. These indices will be used to create the target matrix later.

# %%
relevant_description_idx = []
description_subset = []
for idx, row in enumerate(y_mat): 
    has_relevant_tag = np.sum(row[idx_of_selected_tags])>0
    has_utility_tag = np.sum(row[idx_of_utility_tags])>0 #
    if has_relevant_tag & ~has_utility_tag:
        relevant_description_idx.append(idx)
        description_subset.append(descriptions[idx])

# %% [markdown]
# Write code to filter out game descriptions that have no information

# %%
len(relevant_description_idx)
# Out:
# 14411

# %% [markdown]
# An example of a game

# %%
print(descriptions[relevant_description_idx[3]])
tag_indices = np.where(y_mat[relevant_description_idx[3],:]>0)[0]
for idx in tag_indices:
    print(tag_names[idx])
# Out:
# Discover a new breed of Action-RPG game powered by an enhanced version of the Source™ Engine by Valve. Set in the Might &amp;amp; Magic® universe, players will experience ferocious combat in a dark and immersive fantasy environment. Swords, Stealth, Sorcery. Choose your way to kill.
# Action
# Singleplayer
# Multiplayer
# First-Person
# RPG
# Fantasy
# Adventure
# Medieval
# Action RPG
# Story Rich
# Dark Fantasy
# Swordplay
# Magic
# Classic
# Multiple Endings
# Stealth
# Atmospheric
# Hack and Slash
# Gore
# FPS

# %% [markdown]
# ## Contructing the targete matrix

# %%
y = np.zeros( (len(description_subset), len(idx_of_selected_tags)) )
for i, relevant_game_idx in enumerate(relevant_description_idx):
    y[i,:] = y_mat[relevant_game_idx, idx_of_selected_tags]

# %%
for idx, col in enumerate(idx_of_selected_tags):
    print(int(np.sum(y[:, idx])), tag_names[col])
# Out:
# 2037 Horror
# 2603 Sci-fi
# 302 Futuristic
# 2198 Fantasy
# 408 Medieval
# 314 Dark Fantasy
# 275 Magic
# 731 Gore
# 511 World War II
# 882 Zombies
# 705 Mystery
# 1438 Survival
# 303 Aliens
# 1429 Space
# 75 Supernatural
# 522 Dark
# 97 Gothic
# 110 Western
# 535 War
# 705 Historical
# 377 Military
# 187 Naval
# 2023 Racing
# 383 Post-apocalyptic
# 394 Cyberpunk
# 308 Surreal
# 179 Pirates
# 2356 Sports
# 370 Robots
# 474 Survival Horror
# 165 Crime
# 303 Steampunk
# 78 Mythology
# 140 Dystopian
# 91 World War I
# 118 Psychedelic
# 103 Cold War
# 591 Psychological Horror
# 132 Dragons

# %% [markdown]
# # Going from words to a vector

# %%
def sentence_to_point(description, word_model):
    words = description.split()
    game_vec = np.zeros((300,))
    for word in words:
        if word in word_model.vocab:
            word_vec = word_model.wv[word]
            game_vec = np.add(game_vec, word_vec)
    return game_vec

# %%
word_model = gensim.models.KeyedVectors.load_word2vec_format('./models/GoogleNews-vectors-negative300.bin', binary=True)

# %%
X = np.zeros( (len(description_subset), 300) )
for idx, description in enumerate(description_subset):
    game_vec = sentence_to_point(description, word_model)
    X[idx,:] = game_vec

# %% [markdown]
# # Beginning machine learning

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
model = LogisticRegression()
model_collection = []
for genre in range(0,len(idx_of_selected_tags)): 
    clf_clone = clone(model)
    clf_clone.fit(X_train, y_train[:, genre])
    model_collection.append(clf_clone)

# %%
joblib.dump(model_collection, 'steam_model_collection.pkl')
# Out:
# ['steam_model_collection.pkl']

# %% [markdown]
# Below I make a list of only the tag names used in training the model. The list is used to form the legend in the PR and ROC plot.

# %%
selected_tag_names = []
for idx in idx_of_selected_tags:
    selected_tag_names.append(tag_names[idx])

# %% [markdown]
# Making the PR and ROC plot

# %%
hf.make_roc_pr_plot(X_test, y_test, model_collection, selected_tag_names)

# %% [markdown]
# # Trying it out

# %%
example = 'In a strange future darkness lurks behind every star. With the sun about to collapse, you must find a way for the human rance to survive.'
#example = 'Madness has spread in the town. Zombies are everywhere and blood floods in the streets.'
game_vec = sentence_to_point(example, word_model)

# %%
pred_list = []
for idx, clf in enumerate(model_collection):
    pred = clf.predict_proba(game_vec.reshape(1, -1))
    pred_list.append(pred[:,1])

# %%
sort_idx = sorted(range(len(pred_list)), key=lambda k: pred_list[k], reverse=True)
my_list = [(pred_list[idx], selected_tag_names[idx]) for idx in sort_idx]
for item in my_list:
    proba = item[0][0]
    genre_name = item[1]
    print(genre_name, proba)
# Out:
# Dark 0.501577771113
# Horror 0.489796393067
# Gothic 0.39558751696
# Sci-fi 0.217234986506
# Fantasy 0.190020633877
# Futuristic 0.112818569812
# Surreal 0.108092429549
# Survival 0.0808727241965
# Gore 0.0659831752352
# Space 0.0560402993244
# Mythology 0.0234101938773
# Zombies 0.0217204550805
# War 0.0195242944294
# Psychological Horror 0.0171601378334
# Magic 0.010772993758
# Racing 0.0101976443103
# Dark Fantasy 0.00919474054271
# Steampunk 0.0061283179675
# Survival Horror 0.00573988060209
# Historical 0.0046701824163
# Post-apocalyptic 0.00435030525388
# Psychedelic 0.00254163634137
# Cold War 0.00170926702155
# World War I 0.00159194319358
# Sports 0.00114397718622
# Aliens 0.00103358430851
# Robots 0.000979517113912
# Mystery 0.000944140322433
# Cyberpunk 0.000806351466554
# Military 0.000359337695884
# Medieval 0.000202300632915
# Supernatural 0.000166359032184
# Pirates 3.23831049121e-05
# Dystopian 2.62678145109e-05
# Crime 1.12705392432e-05
# Naval 7.23172210068e-06
# World War II 6.39894829965e-06
# Western 1.46202836821e-06
# Dragons 7.18964218256e-07

# %% [markdown]
# # Using neural networds to do the classification

# %% [markdown]
# The network should be given a string of words, and not the word2vec embedding, which was used in the previous section

# %% [markdown]
# ## Cleaning the strings a bit

# %%
def clean_string(string):
    """
    Tokenization/string cleaning for dataset
    Every dataset is lower cased except
    """
    string = re.sub(r"\\", "", string)    
    string = re.sub(r"\'", "", string)    
    string = re.sub(r"\"", "", string)
    # Replace numbers by x
    string = re.sub("\d", "x", string) 
    string.strip().lower()
    string = remove_stop_words(string)
    return string

def remove_stop_words(description):
    word_list = description.split()
    filtered_words = [word for word in word_list if word not in stopwords.words('english')]
    description = ' '.join(filtered_words)
    return description

# %%
cleaned_description = []
for desc in description_subset:
    desc = clean_string(desc)
    cleaned_description.append(desc)

# %% [markdown]
# # Counting the occourence of words to get top N words

# %%
corpus = ' '.join(cleaned_description)
c = Counter(corpus.split())

# %% [markdown]
# The corpus contains the following number of words:

# %%
len(c)
# Out:
# 34384

# %% [markdown]
# For the embedding we want to use only some of the words. We select the top 5000 words in this case.

# %%
n_words = 10000
top_n_words = c.most_common(n_words)

# %%
top_n_words[:5]
# Out:
# [('game', 3890), ('The', 3320), ('new', 2338), ('world', 1748), ('x', 1568)]

# %%
import pickle 
top_n_words_dict = {}
for idx, item in enumerate(top_n_words):
    word = item[0]
    top_n_words_dict[word] = idx
    
np.save('data/top_n_words_dict.npy', top_n_words_dict)

# %%
def embedding_description(desc, top_n_words_dict):
    game_embedding = []
    for idx, word in enumerate(desc.split()):
        if word in top_n_words_dict:
            word_idx = top_n_words_dict[word]
            game_embedding.append(word_idx)
        else:
            game_embedding.append(0)
    return game_embedding

# %%
embedded_descriptions = []
for desc in cleaned_description:
    game_embedding = []
    for idx, word in enumerate(desc.split()):
        if word in top_n_words_dict:
            word_idx = top_n_words_dict[word]
            game_embedding.append(word_idx)
        else:
            game_embedding.append(0)
    embedded_descriptions.append(game_embedding)

# %%
embedded_descriptions = np.array(embedded_descriptions)

# %% [markdown]
# ## Training a netword based on the embedding

# %%
X_train, X_test, y_train, y_test = train_test_split(embedded_descriptions, y, test_size=0.2, random_state=42)

# %% [markdown]
# ## Saving the train/test split with and without embedding

# %%
np.save('data/X_test.npy', X_test) 
np.save('data/X_train.npy', X_train)

# %%
X_train_descriptions, X_test_descriptions, y_train, y_test = train_test_split(cleaned_description, y, test_size=0.2, random_state=42)
def get_example_from_test_set(X_test):
    rand_int = np.random.randint(0,len(X_test))
    string = X_test[rand_int]
    return string
get_example_from_test_set(X_test)
np.save('data/X_test_descriptions.npy', X_test_descriptions) 
np.save('data/X_train_descriptions.npy', X_train_descriptions)

# %%
X_train.shape
# Out:
# (11528,)

# %%
maxlen = 70

print('Pad sequences (samples x time)')
X_train = sequence.pad_sequences(X_train, maxlen=maxlen)
X_test = sequence.pad_sequences(X_test, maxlen=maxlen)
print('X_train shape:', X_train.shape)
print('X_test shape:', X_test.shape)
# Out:
# Pad sequences (samples x time)
# X_train shape: (11528, 70)
# X_test shape: (2883, 70)

# %%
# Embedding
max_features = n_words
embedding_size = 128

# Convolution
kernel_size = 5
filters = 64
pool_size = 4

# LSTM
lstm_output_size = 50

# Training
batch_size = 100
epochs = 5

# %%
model = Sequential()
model.add(Embedding(max_features, embedding_size, input_length=maxlen))
model.add(Dropout(0.25))
model.add(Conv1D(filters,
                 kernel_size,
                 padding='valid',
                 activation='relu',
                 strides=1))
model.add(MaxPooling1D(pool_size=pool_size))
model.add(LSTM(lstm_output_size))
model.add(Dense(1))
model.add(Activation('sigmoid'))

model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

print(model.input_shape)
print(model.summary())
# Out:
# (None, 70)
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_4 (Embedding)      (None, 70, 128)           1280000
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 70, 128)           0
# _________________________________________________________________
# conv1d_4 (Conv1D)            (None, 66, 64)            41024
# _________________________________________________________________
# max_pooling1d_4 (MaxPooling1 (None, 16, 64)            0
# _________________________________________________________________
# lstm_4 (LSTM)                (None, 50)                23000
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 51
# _________________________________________________________________
# activation_4 (Activation)    (None, 1)                 0
# =================================================================
# Total params: 1,344,075
# Trainable params: 1,344,075
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
nn_model_collection = []
model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])
for genre in range(0,len(idx_of_selected_tags)):
    t0 = time.time()
    model_genre = Sequential()
    model_genre.add(Embedding(max_features, embedding_size, input_length=maxlen))
    model_genre.add(Dropout(0.25))
    model_genre.add(Conv1D(filters,
                     kernel_size,
                     padding='valid',
                     activation='relu',
                     strides=1))
    model_genre.add(MaxPooling1D(pool_size=pool_size))
    model_genre.add(LSTM(lstm_output_size))
    model_genre.add(Dense(1))
    model_genre.add(Activation('sigmoid'))

    model_genre.compile(loss='binary_crossentropy',
                  optimizer='adam',
                  metrics=['accuracy'])
    model_genre.fit(X_train, y_train[:, genre],
              batch_size=batch_size,
              epochs=epochs,
              verbose=0,
              validation_data=(X_test, y_test[:, genre]))
    nn_model_collection.append(model_genre)
    model_genre.save('models/steam_nn_model_collection_' + str(genre) + '.h5')
    print('Done with run ', genre)
    t1 = time.time()
    print(np.ceil((t1-t0)/60), ' min to train the model')
# Out:
# Done with run  0
# 2.0  min to train the model
# Done with run  1
# 2.0  min to train the model
# Done with run  2
# 2.0  min to train the model
# Done with run  3
# 2.0  min to train the model
# Done with run  4
# 2.0  min to train the model
# Done with run  5
# 2.0  min to train the model
# Done with run  6
# 2.0  min to train the model
# Done with run  7
# 2.0  min to train the model
# Done with run  8
# 2.0  min to train the model
# Done with run  9
# 2.0  min to train the model
# Done with run  10
# 2.0  min to train the model
# Done with run  11
# 2.0  min to train the model
# Done with run  12
# 2.0  min to train the model
# Done with run  13
# 2.0  min to train the model
# Done with run  14
# 2.0  min to train the model
# Done with run  15
# 2.0  min to train the model
# Done with run  16
# 2.0  min to train the model
# Done with run  17
# 2.0  min to train the model
# Done with run  18
# 2.0  min to train the model
# Done with run  19
# 2.0  min to train the model
# Done with run  20
# 2.0  min to train the model
# Done with run  21
# 2.0  min to train the model
# Done with run  22
# 2.0  min to train the model
# Done with run  23
# 2.0  min to train the model
# Done with run  24
# 2.0  min to train the model
# Done with run  25
# 2.0  min to train the model
# Done with run  26
# 2.0  min to train the model
# Done with run  27
# 2.0  min to train the model
# Done with run  28
# 2.0  min to train the model
# Done with run  29
# 2.0  min to train the model
# Done with run  30
# 2.0  min to train the model
# Done with run  31
# 2.0  min to train the model
# Done with run  32
# 2.0  min to train the model
# Done with run  33
# 2.0  min to train the model
# Done with run  34
# 2.0  min to train the model
# Done with run  35
# 2.0  min to train the model
# Done with run  36
# 2.0  min to train the model
# Done with run  37
# 2.0  min to train the model
# Done with run  38
# 2.0  min to train the model

# %%
hf.make_roc_pr_plot(X_test, y_test, nn_model_collection, selected_tag_names)
# Out:
# 2883/2883 [==============================] - 4s
# 2883/2883 [==============================] - 4s
# 2883/2883 [==============================] - 4s
# 2883/2883 [==============================] - 4s
# 2883/2883 [==============================] - 4s
# 2883/2883 [==============================] - 4s
# 2883/2883 [==============================] - 4s
# 2883/2883 [==============================] - 4s
# 2883/2883 [==============================] - 4s
# 2883/2883 [==============================] - 4s
# 2883/2883 [==============================] - 4s
# 2883/2883 [==============================] - 4s
# 2880/2883 [============================>.] - ETA: 0s

# %% [markdown]
# # Training a single model with an output neuron for each tag

# %% [markdown]
# ## Trying out the network

# %%
def pre_process_for_nn(string, top_n_words_dict):
    string = clean_string(string)
    embedded = embedding_description(string, top_n_words_dict)
    a = [0] * (70 - len(embedded))
    zero_padded_example = np.array(a + embedded).reshape(-1,70)
    return(zero_padded_example)

def make_example_from_index(idx):
    example = descriptions[relevant_description_idx[idx]]
    print(example)
    tag_indices = np.where(y_mat[relevant_description_idx[idx],:]>0)[0]
    for idx in tag_indices:
        print(tag_names[idx])
    return example

def make_prediction_with_nn(zero_padded_example, nn_model_collection, selected_tag_names):
    pred_list = []
    for idx, clf in enumerate(nn_model_collection):
        pred = clf.predict_proba(zero_padded_example, verbose=0)
        pred_list.append(pred)

    sort_idx = sorted(range(len(pred_list)), key=lambda k: pred_list[k], reverse=True)
    my_list = [(pred_list[idx], selected_tag_names[idx]) for idx in sort_idx]
    for item in my_list:
        proba = item[0][0][0]
        genre_name = item[1]
        if proba > 0.05:
            print(genre_name, proba)

# %%
#example = 'In a strange future darkness lurks behind every star. With the sun about to collapse, you must find a way into space for the human rance to survive.'
#example = 'Madness has spread in the town. Zombies are everywhere and blood floods in the streets.'
# Selecting from the game descriptions instead

idx = 1200
example = make_example_from_index(idx)
zero_padded_example = pre_process_for_nn(example)

# %%
make_prediction_with_nn(zero_padded_example, nn_model_collection, selected_tag_names)

# %%
t0 = time.time()
nn_2_model_collection = []
for i in range(len(idx_of_selected_tags)):
    model = load_model('models/steam_nn_model_collection_' + str(i) + '.h5')
    nn_2_model_collection.append(model)
    if i%5==0:
        t1 = time.time()
        print((t1-t0)/60, ' min to load the models')

# %%
example = make_example_from_index(7500)
zero_padded_example = pre_process_for_nn(example)
print('Predicting with neural networks ...')
t0 = time.time()
make_prediction_with_nn(zero_padded_example, nn_2_model_collection, selected_tag_names)
t1 = time.time()
print('It took ', (t1-t0)/60, ' min to make these prediction')

# %% [markdown]
# # Doing LSTM om the word2vec representation of the words

# %% [markdown]
# ## Turning each word into a 300 dim vec

# %%
max_words = 0
for desc in description_subset:
    length = len(desc.split())
    if length > max_words: 
        max_words = length

# %%
def sentence_to_vec(description, max_words, word_model):
    sentence_vec = np.zeros( (300, max_words) )
    words = description.split()
    game_vec = np.zeros((300,))
    idx = 0
    for word in words:
        if word in word_model.vocab:
            word_vec = word_model.wv[word]
            sentence_vec[:, idx] = word_vec
            idx =+ 1
    return sentence_vec

# %%
X_embedded = np.zeros( (len(description_subset), max_words , 300) )
for idx, desc in  enumerate(description_subset):
    sentence_vec = sentence_to_vec(desc, max_words, word_model)
    X_embedded[idx, :, :] = np.transpose(sentence_vec)

# %%
np.shape(X_embedded)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_embedded, y, test_size=0.2)

# %%
X_test.shape

# %% [markdown]
# # Building a simple LSTM

# %%
word_vec_dim = 300

model = Sequential()
model.add(LSTM(max_words, input_shape=(max_words, word_vec_dim)))
model.add(Dense(1, activation='sigmoid'))

model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

print(model.input_shape)
print(model.summary())

# %%
history = model.fit(X_train,
                    y_train[:,0],
                    epochs=10,
                    batch_size=32,
                    verbose=1,
                    validation_data=(X_test, y_test[:,0])
                   )

# %% [markdown]
# # The guide from Machine Learning mastery on IMDB data

# %% [markdown]
# The CNN LSTM neural network below is taken directly from: https://github.com/fchollet/keras/blob/master/examples/imdb_cnn_lstm.py
